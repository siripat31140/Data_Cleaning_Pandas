# %% [markdown]
# # FIFA 2018 - Players' Personal Data
# data source:
# * https://sofifa.com/
# * https://www.kaggle.com/thec03u5/fifa-18-demo-player-dataset

# %% [markdown]
# ## Objective:
# * clean currency string
#     - €95.5M to 95.5 or 95500000

# %% [markdown]
# ---
# * author: Prasert Kanawattanachai
# * e-mail: prasert.k@chula.ac.th
# * [Chulalongkorn Business School, Thailand](https://www.cbs.chula.ac.th/en/home/)
# ---

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('', width=720, height=405)
# Out:
#         <iframe
#             width="720"
#             height="405"
#             src="https://www.youtube.com/embed/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
print(f"pandas  version = {pd.__version__}")
print(f"seaborn version = {sns.__version__}")
# Out:
# pandas  version = 0.24.2
# seaborn version = 0.9.0

# %%
pd.set_option('display.max_columns', 0,
              'display.max_colwidth', 0)

# %%
from datetime import datetime
str(datetime.now())
# Out:
# '2019-05-18 09:27:50.065933'

# %%
url='https://github.com/prasertcbs/basic-dataset/raw/master/FIFA2018/PlayerPersonalData.csv'
df = pd.read_csv(url)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1      ID  ...   Value   Wage Special
# 0  0           0             20801   ...  €95.5M  €565K  2228
# 1  1           1             158023  ...  €105M   €565K  2154
# 2  2           2             190871  ...  €123M   €280K  2100
# 3  3           3             176580  ...  €97M    €510K  2291
# 4  4           4             167495  ...  €61M    €230K  1493
#
# [5 rows x 15 columns]

# %%
df.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'Photo', 'Flag', 'Club Logo'], inplace=True)
df.head()
# Out:
#        ID               Name  Age  ...   Value   Wage  Special
# 0  20801   Cristiano Ronaldo  32   ...  €95.5M  €565K  2228
# 1  158023  L. Messi           30   ...  €105M   €565K  2154
# 2  190871  Neymar             25   ...  €123M   €280K  2100
# 3  176580  L. Suárez          30   ...  €97M    €510K  2291
# 4  167495  M. Neuer           31   ...  €61M    €230K  1493
#
# [5 rows x 10 columns]

# %%
# df.to_csv('fifa2018player.csv', index=False)

# %%
df.rename(columns={"Value": "Value_EUR", "Wage": "Wage_EUR"}, inplace=True)
df.head()
# Out:
#        ID               Name  Age  ... Value_EUR  Wage_EUR  Special
# 0  20801   Cristiano Ronaldo  32   ...  €95.5M    €565K     2228
# 1  158023  L. Messi           30   ...  €105M     €565K     2154
# 2  190871  Neymar             25   ...  €123M     €280K     2100
# 3  176580  L. Suárez          30   ...  €97M      €510K     2291
# 4  167495  M. Neuer           31   ...  €61M      €230K     1493
#
# [5 rows x 10 columns]

# %%
df['Value_EUR'].str[-1][:5]
# Out:
# 0    M
# 1    M
# 2    M
# 3    M
# 4    M
# Name: Value_EUR, dtype: object

# %%
df['Value_EUR'].str[-1].unique()
# Out:
# array(['M', '0', 'K'], dtype=object)

# %%
def value_unit(s: str):
    s=s.strip().upper()
    if s[-1] == 'M':
        return 1e6
    elif s[-1] == 'K':
        return 1000
    else:
        return 1

# %%
value_unit('€50.5m')
# Out:
# 1000000.0

# %%
import re
def str_value(s: str):
    mul=value_unit(s)
    return float(re.sub(r'[^0-9.]', '', s)) * mul

# %%
str_value('€50.2')
# Out:
# 50.2

# %%
df[['Value_EUR', 'Wage_EUR']][:10]
# Out:
#   Value_EUR Wage_EUR
# 0  €95.5M    €565K
# 1  €105M     €565K
# 2  €123M     €280K
# 3  €97M      €510K
# 4  €61M      €230K
# 5  €92M      €355K
# 6  €64.5M    €215K
# 7  €90.5M    €295K
# 8  €79M      €340K
# 9  €77M      €275K

# %%
df[['Value_EUR', 'Wage_EUR']].applymap(lambda s: str_value(s))[:10]
# Out:
#      Value_EUR  Wage_EUR
# 0  95500000.0   565000.0
# 1  105000000.0  565000.0
# 2  123000000.0  280000.0
# 3  97000000.0   510000.0
# 4  61000000.0   230000.0
# 5  92000000.0   355000.0
# 6  64500000.0   215000.0
# 7  90500000.0   295000.0
# 8  79000000.0   340000.0
# 9  77000000.0   275000.0

# %%
df[['Value_EUR', 'Wage_EUR']]=df[['Value_EUR', 'Wage_EUR']].applymap(lambda s: str_value(s))
df.head()
# Out:
#        ID               Name  Age  ...    Value_EUR  Wage_EUR  Special
# 0  20801   Cristiano Ronaldo  32   ...  95500000.0   565000.0  2228
# 1  158023  L. Messi           30   ...  105000000.0  565000.0  2154
# 2  190871  Neymar             25   ...  123000000.0  280000.0  2100
# 3  176580  L. Suárez          30   ...  97000000.0   510000.0  2291
# 4  167495  M. Neuer           31   ...  61000000.0   230000.0  1493
#
# [5 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17981 entries, 0 to 17980
# Data columns (total 10 columns):
# ID             17981 non-null int64
# Name           17981 non-null object
# Age            17981 non-null int64
# Nationality    17981 non-null object
# Overall        17981 non-null int64
# Potential      17981 non-null int64
# Club           17733 non-null object
# Value_EUR      17981 non-null float64
# Wage_EUR       17981 non-null float64
# Special        17981 non-null int64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 1.4+ MB

# %%
# df.to_csv('fifa2018_player_personal_data.csv', index=False)

# %%
df.sort_values('Value_EUR', ascending=False).head(10)
# Out:
#         ID               Name  Age  ...    Value_EUR  Wage_EUR  Special
# 2   190871  Neymar             25   ...  123000000.0  280000.0  2100
# 1   158023  L. Messi           30   ...  105000000.0  565000.0  2154
# 3   176580  L. Suárez          30   ...  97000000.0   510000.0  2291
# 0   20801   Cristiano Ronaldo  32   ...  95500000.0   565000.0  2228
# 5   188545  R. Lewandowski     28   ...  92000000.0   355000.0  2143
# 7   183277  E. Hazard          26   ...  90500000.0   295000.0  2096
# 11  192985  K. De Bruyne       26   ...  83000000.0   285000.0  2162
# 8   182521  T. Kroos           27   ...  79000000.0   340000.0  2165
# 19  211110  P. Dybala          23   ...  79000000.0   215000.0  2063
# 9   167664  G. Higuaín         29   ...  77000000.0   275000.0  1961
#
# [10 rows x 10 columns]

# %%
df.nlargest(10, 'Value_EUR')
# Out:
#         ID               Name  Age  ...    Value_EUR  Wage_EUR  Special
# 2   190871  Neymar             25   ...  123000000.0  280000.0  2100
# 1   158023  L. Messi           30   ...  105000000.0  565000.0  2154
# 3   176580  L. Suárez          30   ...  97000000.0   510000.0  2291
# 0   20801   Cristiano Ronaldo  32   ...  95500000.0   565000.0  2228
# 5   188545  R. Lewandowski     28   ...  92000000.0   355000.0  2143
# 7   183277  E. Hazard          26   ...  90500000.0   295000.0  2096
# 11  192985  K. De Bruyne       26   ...  83000000.0   285000.0  2162
# 8   182521  T. Kroos           27   ...  79000000.0   340000.0  2165
# 19  211110  P. Dybala          23   ...  79000000.0   215000.0  2063
# 9   167664  G. Higuaín         29   ...  77000000.0   275000.0  1961
#
# [10 rows x 10 columns]

# %%
df.groupby('Club').sum()[['Value_EUR', 'Wage_EUR']].sort_values('Value_EUR', ascending=False).head(10)
# Out:
#                        Value_EUR   Wage_EUR
# Club
# Real Madrid CF       826700000.0  4751000.0
# FC Bayern Munich     748825000.0  3273000.0
# FC Barcelona         744500000.0  4792000.0
# Chelsea              673085000.0  3537000.0
# Paris Saint-Germain  631750000.0  2198000.0
# Manchester United    625300000.0  3653000.0
# Juventus             617100000.0  3165000.0
# Manchester City      578215000.0  3152000.0
# Atlético Madrid      566150000.0  1581000.0
# Tottenham Hotspur    516955000.0  2179000.0

# %%
fig, ax=plt.subplots(figsize=(10, 6))
df.groupby('Club').sum()[['Value_EUR']].sort_values('Value_EUR', ascending=False).head(10).plot(kind='barh', ax=ax);
