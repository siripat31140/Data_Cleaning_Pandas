# %% [markdown]
# # cut (binning) and category

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
pd.__version__
# Out:
# '0.22.0'

# %%
df=pd.read_csv('https://github.com/prasertcbs/tutorial/raw/master/staff.csv', 
               index_col='empID', 
               thousands=',', parse_dates=['dob', 'join_date'])
df
# Out:
#            fname          lname sex        dob          position department  \
# empID
# 604       กันตภณ      ซ่อนกลิ่น   M 1994-03-05         ผู้จัดการ         HR
# 607       เกศินี        สายหยุด   F 1968-12-06  ผู้ช่วยผู้จัดการ        FIN
# 486     ชัชลัญญา         ลั่นทม   F 1987-06-01  ผู้ช่วยผู้จัดการ        FIN
# 229      ชาติไทย   เสี้ยวดอกแดง   M 1991-07-27   พนักงานระดับต้น        MKT
# 901       โชติมา         อรคนธ์   F 1974-08-21      รองผู้จัดการ        MKT
# 944    ฐิติรัตน์         ตันหยง   F 1975-08-15   พนักงานระดับต้น         HR
# 405        ณภัทร           มณฑา   M 1963-11-08   พนักงานระดับต้น        FIN
# 665        ณัชชา        สนสร้อย   F 1983-06-17       ผู้ชำนาญงาน        ACC
# 41      ณัฐญาณิน         มะลิลา   F 1987-02-11         ผู้จัดการ        MKT
# 171         ณิชา         ประดู่   F 1962-04-03   พนักงานระดับต้น         HR
# 51         ณิรดา   คัดเค้าเครือ   F 1972-04-27         ผู้จัดการ        MKT
# 724       เดชชัย  พุทธชาติสามสี   M 1983-05-13  ผู้ช่วยผู้จัดการ        MKT
#
#        salary  join_date
# empID
# 604     13000 2016-02-28
# 607     40000 1987-11-30
# 486     25000 2009-05-26
# 229     39000 2015-07-21
# 901     82500 2007-09-18
# 944     38000 1996-08-09
# 405     35000 1984-11-02
# 665     21000 2017-03-11
# 41      36000 2012-02-05
# 171     25000 2017-03-28
# 51     101500 2001-10-29
# 724     77500 2004-03-08

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 604 to 724
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   fname       12 non-null     object
#  1   lname       12 non-null     object
#  2   sex         12 non-null     object
#  3   dob         12 non-null     datetime64[ns]
#  4   position    12 non-null     object
#  5   department  12 non-null     object
#  6   salary      12 non-null     int64
#  7   join_date   12 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(5)
# memory usage: 864.0+ bytes

# %%
# old way (before 0.21.0)
salary_bucket=['0-15,000', '15,001-30,000', '30,001-50,000', '50,001-80,000', '80,001+']
df['salary_group'] = pd.cut(df.salary,
                           bins=[0, 15000, 30000, 50000, 80000, np.inf],
                           labels=salary_bucket,
                           right=True).astype(str).astype("category", categories=salary_bucket, ordered=True)
df.sort_values(by='salary_group')
# Out:
# C:\Users\prasert\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
#            fname          lname sex        dob          position department  \
# empID
# 604       กันตภณ      ซ่อนกลิ่น   M 1994-03-05         ผู้จัดการ         HR
# 486     ชัชลัญญา         ลั่นทม   F 1987-06-01  ผู้ช่วยผู้จัดการ        FIN
# 665        ณัชชา        สนสร้อย   F 1983-06-17       ผู้ชำนาญงาน        ACC
# 171         ณิชา         ประดู่   F 1962-04-03   พนักงานระดับต้น         HR
# 607       เกศินี        สายหยุด   F 1968-12-06  ผู้ช่วยผู้จัดการ        FIN
# 229      ชาติไทย   เสี้ยวดอกแดง   M 1991-07-27   พนักงานระดับต้น        MKT
# 944    ฐิติรัตน์         ตันหยง   F 1975-08-15   พนักงานระดับต้น         HR
# 405        ณภัทร           มณฑา   M 1963-11-08   พนักงานระดับต้น        FIN
# 41      ณัฐญาณิน         มะลิลา   F 1987-02-11         ผู้จัดการ        MKT
# 724       เดชชัย  พุทธชาติสามสี   M 1983-05-13  ผู้ช่วยผู้จัดการ        MKT
# 901       โชติมา         อรคนธ์   F 1974-08-21      รองผู้จัดการ        MKT
# 51         ณิรดา   คัดเค้าเครือ   F 1972-04-27         ผู้จัดการ        MKT
#
#        salary  join_date   salary_group
# empID
# 604     13000 2016-02-28       0-15,000
# 486     25000 2009-05-26  15,001-30,000
# 665     21000 2017-03-11  15,001-30,000
# 171     25000 2017-03-28  15,001-30,000
# 607     40000 1987-11-30  30,001-50,000
# 229     39000 2015-07-21  30,001-50,000
# 944     38000 1996-08-09  30,001-50,000
# 405     35000 1984-11-02  30,001-50,000
# 41      36000 2012-02-05  30,001-50,000
# 724     77500 2004-03-08  50,001-80,000
# 901     82500 2007-09-18        80,001+
# 51     101500 2001-10-29        80,001+

# %%
# new way in pandas 0.21.0
from pandas.api.types import CategoricalDtype
salary_bucket=['0-15,000', '15,001-30,000', '30,001-50,000', '50,001-80,000', '80,001+']
df['salary_group'] = pd.cut(df.salary,
                           bins=[0, 15000, 30000, 50000, 80000, np.inf],
                           labels=salary_bucket,
                           right=True).astype(CategoricalDtype(salary_bucket, ordered=True)) #.astype("category", categories=salary_cat, ordered=True)
df.sort_values(by='salary_group')
# Out:
#            fname          lname sex        dob          position department  \
# empID
# 604       กันตภณ      ซ่อนกลิ่น   M 1994-03-05         ผู้จัดการ         HR
# 486     ชัชลัญญา         ลั่นทม   F 1987-06-01  ผู้ช่วยผู้จัดการ        FIN
# 665        ณัชชา        สนสร้อย   F 1983-06-17       ผู้ชำนาญงาน        ACC
# 171         ณิชา         ประดู่   F 1962-04-03   พนักงานระดับต้น         HR
# 607       เกศินี        สายหยุด   F 1968-12-06  ผู้ช่วยผู้จัดการ        FIN
# 229      ชาติไทย   เสี้ยวดอกแดง   M 1991-07-27   พนักงานระดับต้น        MKT
# 944    ฐิติรัตน์         ตันหยง   F 1975-08-15   พนักงานระดับต้น         HR
# 405        ณภัทร           มณฑา   M 1963-11-08   พนักงานระดับต้น        FIN
# 41      ณัฐญาณิน         มะลิลา   F 1987-02-11         ผู้จัดการ        MKT
# 724       เดชชัย  พุทธชาติสามสี   M 1983-05-13  ผู้ช่วยผู้จัดการ        MKT
# 901       โชติมา         อรคนธ์   F 1974-08-21      รองผู้จัดการ        MKT
# 51         ณิรดา   คัดเค้าเครือ   F 1972-04-27         ผู้จัดการ        MKT
#
#        salary  join_date   salary_group
# empID
# 604     13000 2016-02-28       0-15,000
# 486     25000 2009-05-26  15,001-30,000
# 665     21000 2017-03-11  15,001-30,000
# 171     25000 2017-03-28  15,001-30,000
# 607     40000 1987-11-30  30,001-50,000
# 229     39000 2015-07-21  30,001-50,000
# 944     38000 1996-08-09  30,001-50,000
# 405     35000 1984-11-02  30,001-50,000
# 41      36000 2012-02-05  30,001-50,000
# 724     77500 2004-03-08  50,001-80,000
# 901     82500 2007-09-18        80,001+
# 51     101500 2001-10-29        80,001+

# %%
df.salary_group
# Out:
# empID
# 604         0-15,000
# 607    30,001-50,000
# 486    15,001-30,000
# 229    30,001-50,000
# 901          80,001+
# 944    30,001-50,000
# 405    30,001-50,000
# 665    15,001-30,000
# 41     30,001-50,000
# 171    15,001-30,000
# 51           80,001+
# 724    50,001-80,000
# Name: salary_group, dtype: category
# Categories (5, object): [0-15,000 < 15,001-30,000 < 30,001-50,000 < 50,001-80,000 < 80,001+]

# %%
df.salary_group.hist(grid=False)

# %%
pd.to_datetime('today').year
# Out:
# 2018

# %%
df['age']=pd.to_datetime('today').year - df.dob.dt.year
df
# Out:
#            fname          lname sex        dob          position department  \
# empID
# 604       กันตภณ      ซ่อนกลิ่น   M 1994-03-05         ผู้จัดการ         HR
# 607       เกศินี        สายหยุด   F 1968-12-06  ผู้ช่วยผู้จัดการ        FIN
# 486     ชัชลัญญา         ลั่นทม   F 1987-06-01  ผู้ช่วยผู้จัดการ        FIN
# 229      ชาติไทย   เสี้ยวดอกแดง   M 1991-07-27   พนักงานระดับต้น        MKT
# 901       โชติมา         อรคนธ์   F 1974-08-21      รองผู้จัดการ        MKT
# 944    ฐิติรัตน์         ตันหยง   F 1975-08-15   พนักงานระดับต้น         HR
# 405        ณภัทร           มณฑา   M 1963-11-08   พนักงานระดับต้น        FIN
# 665        ณัชชา        สนสร้อย   F 1983-06-17       ผู้ชำนาญงาน        ACC
# 41      ณัฐญาณิน         มะลิลา   F 1987-02-11         ผู้จัดการ        MKT
# 171         ณิชา         ประดู่   F 1962-04-03   พนักงานระดับต้น         HR
# 51         ณิรดา   คัดเค้าเครือ   F 1972-04-27         ผู้จัดการ        MKT
# 724       เดชชัย  พุทธชาติสามสี   M 1983-05-13  ผู้ช่วยผู้จัดการ        MKT
#
#        salary  join_date   salary_group  age
# empID
# 604     13000 2016-02-28       0-15,000   24
# 607     40000 1987-11-30  30,001-50,000   50
# 486     25000 2009-05-26  15,001-30,000   31
# 229     39000 2015-07-21  30,001-50,000   27
# 901     82500 2007-09-18        80,001+   44
# 944     38000 1996-08-09  30,001-50,000   43
# 405     35000 1984-11-02  30,001-50,000   55
# 665     21000 2017-03-11  15,001-30,000   35
# 41      36000 2012-02-05  30,001-50,000   31
# 171     25000 2017-03-28  15,001-30,000   56
# 51     101500 2001-10-29        80,001+   46
# 724     77500 2004-03-08  50,001-80,000   35

# %%
age_cat = ["18-25", "26-30", "31-40", "41-50", "50+"]
df['age_group'] = pd.cut(df.age, 
         bins=[18, 25, 30, 40, 50, np.Inf], 
         labels= age_cat,
         right=True, 
         include_lowest=True).astype(str).astype("category", categories=age_cat, ordered=True)
df
# Out:
# C:\Users\prasert\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
#            fname          lname sex        dob          position department  \
# empID
# 604       กันตภณ      ซ่อนกลิ่น   M 1994-03-05         ผู้จัดการ         HR
# 607       เกศินี        สายหยุด   F 1968-12-06  ผู้ช่วยผู้จัดการ        FIN
# 486     ชัชลัญญา         ลั่นทม   F 1987-06-01  ผู้ช่วยผู้จัดการ        FIN
# 229      ชาติไทย   เสี้ยวดอกแดง   M 1991-07-27   พนักงานระดับต้น        MKT
# 901       โชติมา         อรคนธ์   F 1974-08-21      รองผู้จัดการ        MKT
# 944    ฐิติรัตน์         ตันหยง   F 1975-08-15   พนักงานระดับต้น         HR
# 405        ณภัทร           มณฑา   M 1963-11-08   พนักงานระดับต้น        FIN
# 665        ณัชชา        สนสร้อย   F 1983-06-17       ผู้ชำนาญงาน        ACC
# 41      ณัฐญาณิน         มะลิลา   F 1987-02-11         ผู้จัดการ        MKT
# 171         ณิชา         ประดู่   F 1962-04-03   พนักงานระดับต้น         HR
# 51         ณิรดา   คัดเค้าเครือ   F 1972-04-27         ผู้จัดการ        MKT
# 724       เดชชัย  พุทธชาติสามสี   M 1983-05-13  ผู้ช่วยผู้จัดการ        MKT
#
#        salary  join_date   salary_group  age age_group
# empID
# 604     13000 2016-02-28       0-15,000   24     18-25
# 607     40000 1987-11-30  30,001-50,000   50     41-50
# 486     25000 2009-05-26  15,001-30,000   31     31-40
# 229     39000 2015-07-21  30,001-50,000   27     26-30
# 901     82500 2007-09-18        80,001+   44     41-50
# 944     38000 1996-08-09  30,001-50,000   43     41-50
# 405     35000 1984-11-02  30,001-50,000   55       50+
# 665     21000 2017-03-11  15,001-30,000   35     31-40
# 41      36000 2012-02-05  30,001-50,000   31     31-40
# 171     25000 2017-03-28  15,001-30,000   56       50+
# 51     101500 2001-10-29        80,001+   46     41-50
# 724     77500 2004-03-08  50,001-80,000   35     31-40

# %%
# recommended way
age_cat = ["18-25", "26-30", "31-40", "41-50", "50+"]
df['age_group'] = pd.cut(df.age, 
         bins=[18, 25, 30, 40, 50, np.Inf], 
         labels= age_cat,
         right=True, 
         include_lowest=True).astype(CategoricalDtype(age_cat, ordered=True))
df
# Out:
#            fname          lname sex        dob          position department  \
# empID
# 604       กันตภณ      ซ่อนกลิ่น   M 1994-03-05         ผู้จัดการ         HR
# 607       เกศินี        สายหยุด   F 1968-12-06  ผู้ช่วยผู้จัดการ        FIN
# 486     ชัชลัญญา         ลั่นทม   F 1987-06-01  ผู้ช่วยผู้จัดการ        FIN
# 229      ชาติไทย   เสี้ยวดอกแดง   M 1991-07-27   พนักงานระดับต้น        MKT
# 901       โชติมา         อรคนธ์   F 1974-08-21      รองผู้จัดการ        MKT
# 944    ฐิติรัตน์         ตันหยง   F 1975-08-15   พนักงานระดับต้น         HR
# 405        ณภัทร           มณฑา   M 1963-11-08   พนักงานระดับต้น        FIN
# 665        ณัชชา        สนสร้อย   F 1983-06-17       ผู้ชำนาญงาน        ACC
# 41      ณัฐญาณิน         มะลิลา   F 1987-02-11         ผู้จัดการ        MKT
# 171         ณิชา         ประดู่   F 1962-04-03   พนักงานระดับต้น         HR
# 51         ณิรดา   คัดเค้าเครือ   F 1972-04-27         ผู้จัดการ        MKT
# 724       เดชชัย  พุทธชาติสามสี   M 1983-05-13  ผู้ช่วยผู้จัดการ        MKT
#
#        salary  join_date   salary_group  age age_group
# empID
# 604     13000 2016-02-28       0-15,000   24     18-25
# 607     40000 1987-11-30  30,001-50,000   50     41-50
# 486     25000 2009-05-26  15,001-30,000   31     31-40
# 229     39000 2015-07-21  30,001-50,000   27     26-30
# 901     82500 2007-09-18        80,001+   44     41-50
# 944     38000 1996-08-09  30,001-50,000   43     41-50
# 405     35000 1984-11-02  30,001-50,000   55       50+
# 665     21000 2017-03-11  15,001-30,000   35     31-40
# 41      36000 2012-02-05  30,001-50,000   31     31-40
# 171     25000 2017-03-28  15,001-30,000   56       50+
# 51     101500 2001-10-29        80,001+   46     41-50
# 724     77500 2004-03-08  50,001-80,000   35     31-40

# %%
df.age_group
# Out:
# empID
# 604    18-25
# 607    41-50
# 486    31-40
# 229    26-30
# 901    41-50
# 944    41-50
# 405      50+
# 665    31-40
# 41     31-40
# 171      50+
# 51     41-50
# 724    31-40
# Name: age_group, dtype: category
# Categories (5, object): [18-25 < 26-30 < 31-40 < 41-50 < 50+]

# %%
df.age_group.hist(grid=False);

# %%
from IPython.display import IFrame
IFrame("https://matplotlib.org/examples/color/named_colors.html", width=800, height=800)
# Out:
#         <iframe
#             width="800"
#             height="800"
#             src="https://matplotlib.org/examples/color/named_colors.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# https://matplotlib.org/examples/color/named_colors.html

pd.crosstab(df.age_group, df.sex).plot(kind='barh', color=['pink', 'deepskyblue'])

# %%
from IPython.display import IFrame
IFrame("https://www.careerplanner.com/Career-Articles/Generations.cfm", width=800, height=800)
# Out:
#         <iframe
#             width="800"
#             height="800"
#             src="https://www.careerplanner.com/Career-Articles/Generations.cfm"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
df.dob.dt.year
# Out:
# empID
# 604    1994
# 607    1968
# 486    1987
# 229    1991
# 901    1974
# 944    1975
# 405    1963
# 665    1983
# 41     1987
# 171    1962
# 51     1972
# 724    1983
# Name: dob, dtype: int64

# %%
def gen(birthdate):
    '''born in generation'''
    y = birthdate.year
    if 1946 <= y <= 1964:
        return 'Baby Boomer'
    elif 1965 <= y <= 1979:
        return 'Gen X'
    elif 1980 <= y <= 1994:
        return 'Gen Y'
    elif 1995 <= y <= 2012:
        return 'Gen Z'
    else:
        return 'Gen Alpha'

# %%
df['gen']=df.dob.map(lambda d: gen(d)).astype('category', 
                                              categories=['Baby Boomer', 'Gen X', 'Gen Y', 'Gen Z', 'Gen Alpha'], 
                                              ordered=True)
df
# Out:
# C:\Users\prasert\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#            fname          lname sex        dob          position department  \
# empID
# 604       กันตภณ      ซ่อนกลิ่น   M 1994-03-05         ผู้จัดการ         HR
# 607       เกศินี        สายหยุด   F 1968-12-06  ผู้ช่วยผู้จัดการ        FIN
# 486     ชัชลัญญา         ลั่นทม   F 1987-06-01  ผู้ช่วยผู้จัดการ        FIN
# 229      ชาติไทย   เสี้ยวดอกแดง   M 1991-07-27   พนักงานระดับต้น        MKT
# 901       โชติมา         อรคนธ์   F 1974-08-21      รองผู้จัดการ        MKT
# 944    ฐิติรัตน์         ตันหยง   F 1975-08-15   พนักงานระดับต้น         HR
# 405        ณภัทร           มณฑา   M 1963-11-08   พนักงานระดับต้น        FIN
# 665        ณัชชา        สนสร้อย   F 1983-06-17       ผู้ชำนาญงาน        ACC
# 41      ณัฐญาณิน         มะลิลา   F 1987-02-11         ผู้จัดการ        MKT
# 171         ณิชา         ประดู่   F 1962-04-03   พนักงานระดับต้น         HR
# 51         ณิรดา   คัดเค้าเครือ   F 1972-04-27         ผู้จัดการ        MKT
# 724       เดชชัย  พุทธชาติสามสี   M 1983-05-13  ผู้ช่วยผู้จัดการ        MKT
#
#        salary  join_date   salary_group  age age_group          gen
# empID
# 604     13000 2016-02-28       0-15,000   24     18-25        Gen Y
# 607     40000 1987-11-30  30,001-50,000   50     41-50        Gen X
# 486     25000 2009-05-26  15,001-30,000   31     31-40        Gen Y
# 229     39000 2015-07-21  30,001-50,000   27     26-30        Gen Y
# 901     82500 2007-09-18        80,001+   44     41-50        Gen X
# 944     38000 1996-08-09  30,001-50,000   43     41-50        Gen X
# 405     35000 1984-11-02  30,001-50,000   55       50+  Baby Boomer
# 665     21000 2017-03-11  15,001-30,000   35     31-40        Gen Y
# 41      36000 2012-02-05  30,001-50,000   31     31-40        Gen Y
# 171     25000 2017-03-28  15,001-30,000   56       50+  Baby Boomer
# 51     101500 2001-10-29        80,001+   46     41-50        Gen X
# 724     77500 2004-03-08  50,001-80,000   35     31-40        Gen Y

# %%
df['gen']=df.dob.map(lambda d: gen(d)).astype(CategoricalDtype( 
                                              categories=['Baby Boomer', 'Gen X', 'Gen Y', 'Gen Z', 'Gen Alpha'], 
                                              ordered=True))
df
# Out:
#            fname          lname sex        dob          position department  \
# empID
# 604       กันตภณ      ซ่อนกลิ่น   M 1994-03-05         ผู้จัดการ         HR
# 607       เกศินี        สายหยุด   F 1968-12-06  ผู้ช่วยผู้จัดการ        FIN
# 486     ชัชลัญญา         ลั่นทม   F 1987-06-01  ผู้ช่วยผู้จัดการ        FIN
# 229      ชาติไทย   เสี้ยวดอกแดง   M 1991-07-27   พนักงานระดับต้น        MKT
# 901       โชติมา         อรคนธ์   F 1974-08-21      รองผู้จัดการ        MKT
# 944    ฐิติรัตน์         ตันหยง   F 1975-08-15   พนักงานระดับต้น         HR
# 405        ณภัทร           มณฑา   M 1963-11-08   พนักงานระดับต้น        FIN
# 665        ณัชชา        สนสร้อย   F 1983-06-17       ผู้ชำนาญงาน        ACC
# 41      ณัฐญาณิน         มะลิลา   F 1987-02-11         ผู้จัดการ        MKT
# 171         ณิชา         ประดู่   F 1962-04-03   พนักงานระดับต้น         HR
# 51         ณิรดา   คัดเค้าเครือ   F 1972-04-27         ผู้จัดการ        MKT
# 724       เดชชัย  พุทธชาติสามสี   M 1983-05-13  ผู้ช่วยผู้จัดการ        MKT
#
#        salary  join_date   salary_group  age age_group          gen
# empID
# 604     13000 2016-02-28       0-15,000   24     18-25        Gen Y
# 607     40000 1987-11-30  30,001-50,000   50     41-50        Gen X
# 486     25000 2009-05-26  15,001-30,000   31     31-40        Gen Y
# 229     39000 2015-07-21  30,001-50,000   27     26-30        Gen Y
# 901     82500 2007-09-18        80,001+   44     41-50        Gen X
# 944     38000 1996-08-09  30,001-50,000   43     41-50        Gen X
# 405     35000 1984-11-02  30,001-50,000   55       50+  Baby Boomer
# 665     21000 2017-03-11  15,001-30,000   35     31-40        Gen Y
# 41      36000 2012-02-05  30,001-50,000   31     31-40        Gen Y
# 171     25000 2017-03-28  15,001-30,000   56       50+  Baby Boomer
# 51     101500 2001-10-29        80,001+   46     41-50        Gen X
# 724     77500 2004-03-08  50,001-80,000   35     31-40        Gen Y

# %%
df['gen']=df.dob.map(lambda d: gen(d)).astype(CategoricalDtype( 
                                              categories=['Baby Boomer', 'Gen X', 'Gen Y', 'Gen Z', 'Gen Alpha'], 
                                              ordered=True))
df

# %%
df[['age', 'age_group', 'gen']].sort_values(by='gen')

# %%
df.gen.hist(grid=False);
