# %%
import pandas as pd

# %%
dat=pd.read_csv('https://github.com/prasertcbs/tutorial/raw/master/mpg.csv')
dat
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
#
# [234 rows x 11 columns]

# %%
df=dat.sample(10).reset_index(drop=True)
df
# Out:
#   manufacturer               model  displ  year  cyl       trans drv  cty  \
# 0   volkswagen                 gti    2.8  1999    6  manual(m5)   f   17
# 1        dodge   dakota pickup 4wd    3.7  2008    6  manual(m6)   4   15
# 2        honda               civic    2.0  2008    4  manual(m6)   f   21
# 3        dodge         caravan 2wd    3.3  1999    6    auto(l4)   f   16
# 4      hyundai              sonata    2.4  1999    4    auto(l4)   f   18
# 5       nissan      pathfinder 4wd    5.6  2008    8    auto(s5)   4   12
# 6        dodge         caravan 2wd    4.0  2008    6    auto(l6)   f   16
# 7   volkswagen          new beetle    2.5  2008    5  manual(m5)   f   20
# 8         jeep  grand cherokee 4wd    4.7  2008    8    auto(l5)   4   14
# 9        dodge         durango 4wd    5.9  1999    8    auto(l4)   4   11
#
#    hwy fl       class
# 0   24  r     compact
# 1   19  r      pickup
# 2   29  p  subcompact
# 3   22  r     minivan
# 4   26  r     midsize
# 5   18  p         suv
# 6   23  r     minivan
# 7   28  r  subcompact
# 8   19  r         suv
# 9   15  r         suv

# %%
df.manufacturer.str.capitalize()   #ทำให้ตัวเเรกตัวใหญ่
# Out:
# 0    Volkswagen
# 1         Dodge
# 2         Honda
# 3         Dodge
# 4       Hyundai
# 5        Nissan
# 6         Dodge
# 7    Volkswagen
# 8          Jeep
# 9         Dodge
# Name: manufacturer, dtype: object

# %%
df['trans_am']=df.trans.map(lambda v: 'Auto' if v[0]=='a' else 'Manual').astype('category')
df
# Out:
#   manufacturer               model  displ  year  cyl       trans drv  cty  \
# 0   volkswagen                 gti    2.8  1999    6  manual(m5)   f   17
# 1        dodge   dakota pickup 4wd    3.7  2008    6  manual(m6)   4   15
# 2        honda               civic    2.0  2008    4  manual(m6)   f   21
# 3        dodge         caravan 2wd    3.3  1999    6    auto(l4)   f   16
# 4      hyundai              sonata    2.4  1999    4    auto(l4)   f   18
# 5       nissan      pathfinder 4wd    5.6  2008    8    auto(s5)   4   12
# 6        dodge         caravan 2wd    4.0  2008    6    auto(l6)   f   16
# 7   volkswagen          new beetle    2.5  2008    5  manual(m5)   f   20
# 8         jeep  grand cherokee 4wd    4.7  2008    8    auto(l5)   4   14
# 9        dodge         durango 4wd    5.9  1999    8    auto(l4)   4   11
#
#    hwy fl       class trans_am
# 0   24  r     compact   Manual
# 1   19  r      pickup   Manual
# 2   29  p  subcompact   Manual
# 3   22  r     minivan     Auto
# 4   26  r     midsize     Auto
# 5   18  p         suv     Auto
# 6   23  r     minivan     Auto
# 7   28  r  subcompact   Manual
# 8   19  r         suv     Auto
# 9   15  r         suv     Auto

# %%
def am(v):
    if v[0]=='a':
        return 'Auto'
    else:
        return 'Manual'

# %%
df.trans.map(am)
# Out:
# 0    Manual
# 1    Manual
# 2    Manual
# 3      Auto
# 4      Auto
# 5      Auto
# 6      Auto
# 7    Manual
# 8      Auto
# 9      Auto
# Name: trans, dtype: object

# %%
df['drv2']=df.drv.map({'f':'Front', 'r':'Rear', '4':'4-wheel'}).astype('category')
df
# Out:
#   manufacturer               model  displ  year  cyl       trans drv  cty  \
# 0   volkswagen                 gti    2.8  1999    6  manual(m5)   f   17
# 1        dodge   dakota pickup 4wd    3.7  2008    6  manual(m6)   4   15
# 2        honda               civic    2.0  2008    4  manual(m6)   f   21
# 3        dodge         caravan 2wd    3.3  1999    6    auto(l4)   f   16
# 4      hyundai              sonata    2.4  1999    4    auto(l4)   f   18
# 5       nissan      pathfinder 4wd    5.6  2008    8    auto(s5)   4   12
# 6        dodge         caravan 2wd    4.0  2008    6    auto(l6)   f   16
# 7   volkswagen          new beetle    2.5  2008    5  manual(m5)   f   20
# 8         jeep  grand cherokee 4wd    4.7  2008    8    auto(l5)   4   14
# 9        dodge         durango 4wd    5.9  1999    8    auto(l4)   4   11
#
#    hwy fl       class trans_am     drv2
# 0   24  r     compact   Manual    Front
# 1   19  r      pickup   Manual  4-wheel
# 2   29  p  subcompact   Manual    Front
# 3   22  r     minivan     Auto    Front
# 4   26  r     midsize     Auto    Front
# 5   18  p         suv     Auto  4-wheel
# 6   23  r     minivan     Auto    Front
# 7   28  r  subcompact   Manual    Front
# 8   19  r         suv     Auto  4-wheel
# 9   15  r         suv     Auto  4-wheel
